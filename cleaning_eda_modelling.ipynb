# %%
import pandas as pd
import requests
import pymysql

# %%
community = requests.get("http://127.0.0.1:5000/community")
taxi = requests.get("http://127.0.0.1:5000/taxi")
company = requests.get("http://127.0.0.1:5000/company")
location = requests.get("http://127.0.0.1:5000/location")
trips = requests.get("http://127.0.0.1:5000/trips/4/") #only American United (company_id = 4) called

# %%
community = community.json()
community = pd.json_normalize(community)

taxi = taxi.json()
taxi = pd.json_normalize(taxi)

company = company.json()
company = pd.json_normalize(company)

location = location.json()
location = pd.json_normalize(location)

trips = trips.json()
trips = trips['data']
trips = pd.json_normalize(trips)

# %%
display(trips.head())
display(community.head())
display(taxi.head())
display(company.head())
display(location.head())
# Out:
#    company_id  dropoff_community_area dropoff_latitude  \
# 0           4                      32        41.884987
# 1           4                      32        41.877406
# 2           4                      56        41.792592
# 3           4                       8        41.892508
# 4           4                       8        41.893216
#
#               dropoff_location dropoff_longitude extras   fare payment_type  \
# 0  41.884987192, -87.620992913        -87.620993   1.50   5.45  Credit Card
# 1  41.877406123, -87.621971652        -87.621972   0.00   6.65  Credit Card
# 2   41.79259236, -87.769615453        -87.769615   2.00  34.65         Cash
# 3  41.892507781, -87.626214906        -87.626215   0.50   6.85  Credit Card
# 4    41.89321636, -87.63784421        -87.637844   0.00   5.45  Credit Card
#
#    pickup_community_area pickup_latitude              pickup_location  \
# 0                     32       41.880994  41.880994471, -87.632746489
# ...

# %%
# Out:
# (1000, 20)
